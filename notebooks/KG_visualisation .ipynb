# %%
# !pip install pyvis networkx
# Out:
# Requirement already satisfied: pyvis in /usr/local/lib/python3.12/dist-packages (0.3.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.5)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.12/dist-packages (from pyvis) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from pyvis) (4.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9.6->pyvis) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.14)

# %%
import json

filename ='/content/dse_kg (2).json'
data = json.load(open(filename))
data
# Out:
# {'nodes': [{'id': 'vaibhav',
#    'name': 'Vaibhav Kumar',
#    'email': 'vaibhav@iiserb.ac.in',
#    'department': 'DSE',
#    'position': 'Assistant Professor',
#    'joined_year': None,
#    'homepage': 'https://sites.google.com/view/vaibhavkumar1/home'},
#   {'id': 'tanmay',
#    'name': 'Tanmay Basu',
#    'email': 'tanmay@iiserb.ac.in',
#    'department': 'DSE',
#    'position': 'Assistant Professor',
#    'joined_year': None,
#    'homepage': 'https://sites.google.com/view/tanmaybasu/'},
#   {'id': 'jasabanta',
#    'name': 'Jasabanta Patro',
#    'email': 'jpatro@iiserb.ac.in',
#    'department': 'DSE',
#    'position': 'Assistant Professor',
#    'joined_year': None,
#    'homepage': 'https://sites.google.com/view/jpatro/home'},
#   {'id': 'vinod',
#    'name': 'Vinod K Kurmi',
#    'email': 'vinodkk@iiserb.ac.in',
#    'department': 'DSE',
#    'position': 'Assistant Professor',
#    'joined_year': None,
#    'homepage': 'https://vinodkkurmi.github.io/'},
#   {'id': 'akshay',
#    'name': 'Akshay Agarwal',
#    'email': 'akagarwal@iiserb.ac.in',
#    'department': 'DSE',
#    'position': 'Assistant Professor',
#    'joined_year': None,
#    'homepage': 'https://sites.google.com/iiitd.ac.in/agarwalakshay/home'},
#   {'id': 'samiran',
#    'name': 'Samiran Das',
#    'email': 'samiran@iiserb.ac.in',
#    'department': 'DSE',
#    'position': 'Assistant Professor',
#    'joined_year': None,
#    'homepage': None},
#   {'type': 'Faculty',
#    'id': 'Samiran Das',
#    'name': 'Samiran Das',
#    'email': 'samiran@iiserb.ac.in',
#    'department': 'Computer Science',
#    'position': 'Professor',
#    'joined_year': None},
#   {'id': 'Akash Anil',
#    'name': 'Akash Anil',
#    'email': 'https://sites.google.com/view/akash-anil',
#    'department': 'IISER Bhopal',
#    'position': 'Faculty'},
#   {'id': 'Sundaram Muthu',
#    'name': 'Sundaram Muthu',
#    'email': 'https://tbvl22.github.io/website/home.html',
#    'department': 'IISER Bhopal',
#    'position': 'Faculty'},
#   {'type': 'PhD',
#    'id': 'Shubhi Gehlot',
#    'name': 'Ms. Shubhi Gehlot',
#    'roll_no': None,
#    'email': 'shubhi24@iiserb.ac.in',
#    'department': 'Computer Science',
#    'linkedin': None,
#    'github': 'https://shubhigehlot21.github.io/My_Website/',
#    'research_group': None,
#    'guide': 'Akshay Agarwal'},
#   {'type': 'PhD',
#    'id': 'Bhanu Pratap Paregi',
#    'name': 'Mr. Bhanu Pratap Paregi',
#    'roll_no': None,
#    'email': 'bhanu24@iiserb.ac.in',
#    'department': 'Computer Science',
#    'linkedin': None,
#    'github': 'https://sites.google.com/view/bhanu-paregiphd-scholar',
#    'research_group': None,
#    'guide': 'Vaibhav kumar'},
#   {'type': 'PhD',
#    'id': 'Prateek Sarangi',
#    'name': 'Mr. Prateek Sarangi',
#    'roll_no': None,
#    'email': 'prateek24@iiserb.ac.in',
#    'department': 'Computer Science',
#    'linkedin': None,
#    'github': 'https://sites.google.com/view/prateeksarangi/',
#    'research_group': None,
#    'guide': 'Tanmay Basu'},
#   {'type': 'PhD',
#    'id': 'Ramen Ghosh',
#    'name': 'Mr. Rame n G hosh',
#    'roll_no': None,
#    'email': 'ramen24@iiserb.ac.in',
#    'department': 'Computer Science',
#    'linkedin': None,
#    'github': None,
#    'research_group': None,
#    'guide': 'Samiran Das'},
#   {'id': 'kunal24',
#    'name': 'Mr. Kunal J angid',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'kunal24@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://kunaljangid01.github.io/',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Vinod K Kurmi'},
#   {'id': 'poulomi24',
#    'name': 'Ms. Poulomi Bhattacharya',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'poulomi24@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://poulomi891.github.io/Poulomi/',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Akshay Agarwal'},
#   {'id': 'saarthi24',
#    'name': 'Ms. S Aarthi',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'saarthi24@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://saarthi25.github.io/S_Aarthi/',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Akshay Agarwal'},
#   {'id': 'ayushg24',
#    'name': 'M r . Ayush Garg',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'ayushg24@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://ayushs-garg.github.io/',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Jasabanta Patro'},
#   {'id': 'pavanrajak',
#    'name': 'Pavan Rajak',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'pavanrajak405@gmail.com',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://pavanrajak.github.io/pavan/',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Akshay Agarwal'},
#   {'id': 'atulk23',
#    'name': 'Mr. Atul Kumar',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'atulk23@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://atulkr05.github.io/',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Akshay Agarwal'},
#   {'id': 'shivangir23',
#    'name': 'Shivangi Rai',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'shivangir23@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://shivangiraii.github.io/',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Vinod K Kurmi'},
#   {'id': 'hemantpramanick',
#    'name': 'Hemant Kumar',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'hemantpramanick@gmail.com',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://hemantpramanick.github.io/#bio',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Vaibhav Kumar'},
#   {'id': 'surajk',
#    'name': 'Suraj K',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'surajk@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': 'LinkedIn URL',
#    'github': 'https://github.com/surajk',
#    'research_group': 'research group ID',
#    'guide': 'Dr. Vaibhav Kumar'},
#   {'id': 'suraj23',
#    'name': 'Suraj Kanu',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'suraj23@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': '',
#    'research_group': '',
#    'guide': 'Dr. Vaibhav Kumar'},
#   {'id': 'sumit',
#    'name': 'Sumit Kumar',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': 'https://www.linkedin.com/in/sumit-kumar-787203178',
#    'github': '',
#    'research_group': '',
#    'guide': 'Dr. Tanmay Basu'},
#   {'id': 'prachi',
#    'name': 'Prachi Chachondhia',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': '',
#    'research_group': '',
#    'guide': 'Dr. Vaibhav Kumar'},
#   {'id': 'akanksha',
#    'name': 'Akanksha Singh',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': 'https://akankshasingh233.github.io/',
#    'research_group': '',
#    'guide': 'Dr. Vinod k Kurmi'},
#   {'id': 'rasel23',
#    'name': 'Rasel',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': 'rasel23@iiserb.ac.in',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': '',
#    'research_group': '',
#    'guide': 'Dr. Tanmay Basu'},
#   {'id': 'parinita',
#    'name': 'Parinita Nema',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': 'https://parinitanema.github.io/',
#    'research_group': '',
#    'guide': 'Dr. Vinod K. Kurmi'},
#   {'id': 'vishesh',
#    'name': 'Vishesh Kumar',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': 'https://visheshrajput2408.github.io/vishesh.github.io/',
#    'research_group': '',
#    'guide': 'Dr. Akshay Agarwal'},
#   {'id': 'pyarelal',
#    'name': 'Pyare Lal',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': 'https://www.linkedin.com/in/pyarelaldse/',
#    'github': '',
#    'research_group': '',
#    'guide': 'Dr. Vaibhav Kumar'},
#   {'id': 'rajeev',
#    'name': 'Rajeev Ranjan Dwivedi',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': 'https://rajeev-dw9.github.io/',
#    'research_group': '',
#    'guide': 'Dr. Vinod k. Kurmi'},
#   {'id': 'debajyoti',
#    'name': 'Debajyoti Mazumder',
#    'type': 'PhD',
#    'roll_no': 'official roll number',
#    'email': '',
#    'department': 'department ID',
#    'linkedin': '',
#    'github': '',
#    'research_group': '',
#    'guide': ''},
#   {'id': 'Dr. Jasabanta Patro',
#    'name': 'Dr. Jasabanta Patro',
#    'type': 'Faculty',
#    'email': 'office_dse@iiserb.ac.in',
#    'department': 'IISER Bhopal',
#    'position': 'Professor',
#    'joined_year': '2022'},
#   {'id': 'Mr. Gaurav Kumar',
#    'name': 'Mr. Gaurav Kumar',
#    'type': 'Student',
#    'roll_no': '202',
#    'email': 'gauravkumar62024@gmail.com',
#    'department': 'IISER Bhopal',
#    'linkedin': 'https://www.linkedin.com/in/gauravkumar62024/',
#    'github': 'https://gauravkumar62024.github.io/',
#    'research_group': 'ASIP',
#    'guide': 'Dr. Jasabanta Patro'},
#   {'id': 'Ms. Rini Smita Thakur',
#    'name': 'Ms. Rini Smita Thakur',
#    'type': 'PostDoc',
#    'email': 'rinithakur@iiserb.ac.in',
#    'department': 'IISER Bhopal',
#    'position': 'PostDoc',
#    'joined_year': '2023'},
#   {'id': 'Mr. Anirban Tarafdar',
#    'name': 'Mr. Anirban Tarafdar',
#    'type': 'PostDoc',
#    'email': 'anirbantarafdar@iiserb.ac.in',
#    'department': 'IISER Bhopal',
#    'position': 'PostDoc',
#    'joined_year': '2024'},
#   {'id': 'ASIP',
#    'name': 'Advanced Signal and Image Processing Lab (ASIP)',
#    'type': 'ResearchGroup',
#    'department': 'IISER Bhopal',
#    'head': 'Dr. Jasabanta Patro',
#    'website': 'https://sites.google.com/view/samiran-das/research?authuser=0&pli=1'},
#   {'type': 'ResearchGroup',
#    'id': 'GeoAI4Cities Lab',
#    'name': 'GeoAI4Cities Lab',
#    'department': 'Department of Computer Science',
#    'head': 'Faculty ID',
#    'website': 'https://sites.google.com/iiserb.ac.in/geoai/home'},
#   {'type': 'Institute',
#    'id': 'IISER Bhopal',
#    'name': 'Indian Institute of Science Education and Research Bhopal',
#    'director': 'Dr. Tanmay Basu',
#    'location': 'Bhopal, Madhya Pradesh',
#    'established': '2016'},
#   {'type': 'ResearchGroup',
#    'id': 'ISHA Lab',
#    'name': 'Intelligent Systems and Hypertext Analysis (ISHA) Lab',
#    'department': 'Department of Computer Science',
#    'head': 'Faculty ID',
#    'website': 'https://sites.google.com/iiserb.ac.in/isha-iiserb/home'},
#   {'type': 'ResearchGroup',
#    'id': 'BDS Lab',
#    'name': 'Biomedical Data Science Research Lab',
#    'department': 'Department of Biological Sciences',
#    'head': 'Faculty ID',
#    'website': 'https://sites.google.com/iiserb.ac.in/bds-lab/home'},
#   {'type': 'Faculty',
#    'id': 'Faculty ID',
#    'name': 'Faculty Name',
#    'email': 'faculty_email',
#    'department': 'Department of Biological Sciences',
#    'position': 'Professor',
#    'joined_year': '2020'},
#   {'type': 'Department',
#    'id': 'Department of Computer Science',
#    'name': 'Department of Computer Science',
#    'institute': 'Institute ID',
#    'hod': 'Faculty ID'},
#   {'type': 'Department',
#    'id': 'Department of Biological Sciences',
#    'name': 'Department of Biological Sciences',
#    'institute': 'Institute ID',
#    'hod': 'Faculty ID'},
#   {'type': 'Institute',
#    'id': 'Institute ID',
#    'name': 'IISER Bhopal',
#    'director': 'Director Name',
#    'location': 'Bhopal, Madhya Pradesh',
#    'established': '2008'},
#   {'id': 'bbmed0',
#    'name': 'NLP group at IISERB',
#    'type': 'ResearchGroup',
#    'department': 'Computer Science',
#    'head': 'Faculty ID',
#    'website': 'https://bdslab-iiserb.github.io/'},
#   {'id': 'visdom',
#    'name': 'Visual Data Computing Group (VisDom)',
#    'type': 'ResearchGroup',
#    'department': 'Computer Science',
#    'head': 'Faculty ID',
#    'website': 'https://visdomlab.github.io/'},
#   {'id': 'trustworthy_biometravision_lab',
#    'name': 'Trustworthy BiometraVision Lab',
#    'type': 'ResearchGroup',
#    'department': 'Computer Science',
#    'head': 'Faculty ID',
#    'website': 'Homepage URL'},
#   {'type': 'Institute',
#    'id': 'iiserb',
#    'name': 'IISER Bhopal',
#    'director': None,
#    'location': 'Bhopal, MP',
#    'established': None},
#   {'id': 'computer_science',
#    'name': 'Computer Science',
#    'type': 'Department',
#    'institute': 'iiserb',
#    'hod': 'Faculty ID'},
#   {'id': 'SoDAL Lab',
#    'name': 'Social Data Analytics and Learning Lab',
#    'department': 'IISER Bhopal',
#    'head': 'Akash Anil',
#    'website': 'https://sites.google.com/view/akash-anil'},
#   {'id': 'Robotic Perception and Embodied Intelligence Lab',
#    'name': 'Robotic Perception and Embodied Intelligence Lab',
#    'department': 'IISER Bhopal',
#    'head': 'Sundaram Muthu'},
#   {'id': 'Anay Singh',
#    'name': 'Anay Singh',
#    'type': 'BS',
#    'roll_no': '23045',
#    'email': 'anay23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'Github/LinkedIn',
#    'github': 'https://github.com/crypticBard',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Tanushree Ravindra Pratap Yadav',
#    'name': 'Tanushree Ravindra Pratap Yadav',
#    'type': 'BS',
#    'roll_no': '23380',
#    'email': 'yadav23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'Github/LinkedIn',
#    'github': 'https://github.com/SinUbyCosU',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Sangam',
#    'name': 'Sangam',
#    'type': 'BS',
#    'roll_no': '23290',
#    'email': 'sangam23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'Github/Linkedin',
#    'github': 'https://github.com/sam1511x',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Dev Raj',
#    'name': 'Dev Raj',
#    'type': 'BS',
#    'roll_no': '23102',
#    'email': 'devraj23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'Github/Linkedin',
#    'github': 'https://www.linkedin.com/in/dev-raj-iiserb',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Sankul Rahate',
#    'name': 'Sankul Rahate',
#    'type': 'BS',
#    'roll_no': '23292',
#    'email': 'sankul23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/sankul-rahate-716046227',
#    'github': 'Github/Linkedin',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Kiranmoy Das',
#    'name': 'Kiranmoy Das',
#    'type': 'BS',
#    'roll_no': '23156',
#    'email': 'kiranmoy23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://www.linkedin.com/in/kiranmoy-das-677616323/',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Meghna Yadav',
#    'name': 'Meghna Yadav',
#    'type': 'BS',
#    'roll_no': '23184',
#    'email': 'meghna23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/meghna-yadav-9447512a1?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=ios_app',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Lakshay Saini',
#    'name': 'Lakshay Saini',
#    'type': 'BS',
#    'roll_no': '23166',
#    'email': 'lakshay23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/lakshayxi',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Kushagra Agarwal',
#    'name': 'Kushagra Agarwal',
#    'type': 'BS',
#    'roll_no': '23162',
#    'email': 'kushagra23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://github.com/KushagraAgarwal525',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Ananya Preyasi',
#    'name': 'Ananya Preyasi',
#    'type': 'BS',
#    'roll_no': '23044',
#    'email': 'ananya23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'Anay Singh'},
#   {'type': 'Department',
#    'id': 'NA',
#    'name': 'DSE Students IISER Bhopal',
#    'institute': 'IISER Bhopal',
#    'hod': 'Dr. Tanmay Basu'},
#   {'id': 'Abhishek Nair',
#    'name': 'Abhishek Nair',
#    'type': 'NA',
#    'roll_no': '23009',
#    'email': 'abhisheknair23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/abhishek-nair-054922308',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Palak Kumari',
#    'name': 'Palak Kumari',
#    'type': 'NA',
#    'roll_no': '23217',
#    'email': 'palak23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/palak-kumari-239b39284/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Rachit Bakshi',
#    'name': 'Rachit Bakshi',
#    'type': 'NA',
#    'roll_no': '23254',
#    'email': 'rachit23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/rachit-bakshi-b61899287?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Sarabeshwar Balaji',
#    'name': 'Sarabeshwar Balaji',
#    'type': 'NA',
#    'roll_no': '23294',
#    'email': 'sarabeshwar23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/sarabeshwar-balaji/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Charvi Gupta',
#    'name': 'Charvi Gupta',
#    'type': 'NA',
#    'roll_no': '23091',
#    'email': 'charvi23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/charvi-gupta-620521288',
#    'github': 'https://github.com/Charvi-Gupta',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Pranay Meshram',
#    'name': 'Pranay Meshram',
#    'type': 'NA',
#    'roll_no': '23236',
#    'email': 'pranay23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/pranay-meshram-4a4a3b1b2/',
#    'github': 'https://github.com/praymesh',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Mayank Srivastava',
#    'name': 'Mayank Srivastava',
#    'type': 'NA',
#    'roll_no': '23182',
#    'email': 'mayanks23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/mayank-srivastava-4a4a3b1b2/',
#    'github': 'https://github.com/Mayank-Srivastava-21',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Pragati Nayak',
#    'name': 'Pragati Nayak',
#    'type': 'NA',
#    'roll_no': '23231',
#    'email': 'pragati23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/pragati-nayak-4a4a3b1b2/',
#    'github': 'https://github.com/Pragati-Nayak23',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Chirayu Sakarkar',
#    'name': 'Chirayu Sakarkar',
#    'type': 'NA',
#    'roll_no': '23093',
#    'email': 'chirayus23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/chirayu-sakarkar-4a4a3b1b2/',
#    'github': 'https://github.com/Prowler0204',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Mohammedkaif Mohammedrafiq Kalagond',
#    'name': 'Mohammedkaif Mohammedrafiq Kalagond',
#    'type': 'NA',
#    'roll_no': '23190',
#    'email': 'mohammedkaif23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/mohammedkaif-mohammedrafiq-kalagond-4a4a3b1b2/',
#    'github': 'https://github.com/Mohammedkaif2004',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Kshetrimayum Paresh Singh',
#    'name': 'Kshetrimayum Paresh Singh',
#    'type': 'BS',
#    'roll_no': '23160',
#    'email': 'kshetrimayum23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Atul Sonkar',
#    'name': 'Atul Sonkar',
#    'type': 'NA',
#    'roll_no': '23073',
#    'email': 'atulsonkar23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/atul-sonkar-19a4ab237?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'https://github.com/Atul-Sonkar',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Harshal Digarse',
#    'name': 'Harshal Digarse',
#    'type': 'BS',
#    'roll_no': '23128',
#    'email': 'harshal23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/harshaldigarse',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Sejal Dayma',
#    'name': 'Sejal Dayma',
#    'type': 'BS',
#    'roll_no': '23299',
#    'email': 'sejal23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/sejaldayma',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Lokesh Pareek',
#    'name': 'Lokesh Pareek',
#    'type': 'BS',
#    'roll_no': '23170',
#    'email': 'lokesh23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/lokesh2004-g',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Sayan Samanta',
#    'name': 'Sayan Samanta',
#    'type': 'BS',
#    'roll_no': '23298',
#    'email': 'sayan23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/sayan-samanta-64935b2a6',
#    'github': 'Github / Linkedin',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Satvik Agrawal',
#    'name': 'Satvik Agrawal',
#    'type': 'BS',
#    'roll_no': '23296',
#    'email': 'satvik23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/satvik-agrawal-483a141b8',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'J Paul Masillamani',
#    'name': 'J Paul Masillamani',
#    'type': 'BS',
#    'roll_no': '23141',
#    'email': 'jpaul23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/paul-masillamani-5b1898284?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Singamsetti Komal Sandeep',
#    'name': 'Singamsetti Komal Sandeep',
#    'type': 'BS',
#    'roll_no': '23322',
#    'email': 'singamsetti23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/komal-singamsetti',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Uddisa Kkaarthiek',
#    'name': 'Uddisa Kkaarthiek',
#    'type': 'BS',
#    'roll_no': '23355',
#    'email': 'uddisa23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/kkaarthiek/',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Arnav Shinganjude',
#    'name': 'Arnav Shinganjude',
#    'type': 'BS',
#    'roll_no': '23061',
#    'email': 'arnavs23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/arnav-shinganjude-5601bb354?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'Github / Linkedin',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Nipun Aditya',
#    'name': 'Nipun Aditya',
#    'type': 'BS',
#    'roll_no': '23209',
#    'email': 'nipun23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Ranjith Anand',
#    'name': 'Ranjith Anand',
#    'type': 'BS',
#    'roll_no': '23266',
#    'email': 'ranjith23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/ranjith-anand-9b5649378',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Mohammad Rishan Melethil',
#    'name': 'Mohammad Rishan Melethil',
#    'type': 'BS',
#    'roll_no': '23188',
#    'email': 'rishan23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/mohammad-rishan-melethil-23038a320?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_1',
#    'name': 'Vanshika Gupta',
#    'type': 'BS',
#    'roll_no': '23365',
#    'email': 'vanshikag23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/pawan-kr-rajput',
#    'github': 'https://github.com/Vnshiee/',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_2',
#    'name': 'Nikhil Rathore',
#    'type': 'BS',
#    'roll_no': '23208',
#    'email': 'nikhi23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/nikhil-rathore-38b624351?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_3',
#    'name': 'Jay Jagannath',
#    'type': 'BS',
#    'roll_no': '23145',
#    'email': 'jay23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_4',
#    'name': 'Anay Singh',
#    'type': 'BS',
#    'roll_no': '23045',
#    'email': 'anay23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/crypticBard',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_5',
#    'name': 'Tanushree Ravindra Pratap Yadav',
#    'type': 'BS',
#    'roll_no': '23380',
#    'email': 'yadav23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/SinUbyCosU',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_6',
#    'name': 'Sangam',
#    'type': 'BS',
#    'roll_no': '23290',
#    'email': 'sangam23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/sam1511x',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_7',
#    'name': 'Dev Raj',
#    'type': 'BS',
#    'roll_no': '23102',
#    'email': 'devraj23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/dev-raj-iiserb',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_8',
#    'name': 'Sankul Rahate',
#    'type': 'BS',
#    'roll_no': '23292',
#    'email': 'sankul23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/sankul-rahate-716046227',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_9',
#    'name': 'Kiranmoy Das',
#    'type': 'BS',
#    'roll_no': '23156',
#    'email': 'kiranmoy23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/kiranmoy-das-677616323/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_10',
#    'name': 'Meghna Yadav',
#    'type': 'BS',
#    'roll_no': '23184',
#    'email': 'meghna23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/meghna-yadav-9447512a1?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=ios_app',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_11',
#    'name': 'Lakshay Saini',
#    'type': 'BS',
#    'roll_no': '23166',
#    'email': 'lakshay23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/lakshayxi',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_12',
#    'name': 'Kushagra Agarwal',
#    'type': 'BS',
#    'roll_no': '23162',
#    'email': 'kushagra23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/KushagraAgarwal525',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Student_13',
#    'name': 'Ananya Preyasi',
#    'type': 'BS',
#    'roll_no': '23044',
#    'email': 'ananya23@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/ananya-preyasi-1b45ba340?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'type': 'Faculty',
#    'id': 'Dr. Tanmay Basu',
#    'name': 'Dr. Tanmay Basu',
#    'email': 'hod_dse@iiserb.ac.in',
#    'department': 'DSE',
#    'position': 'Head',
#    'joined_year': '2016'},
#   {'id': 'Data Science and Engineering',
#    'name': 'Department of Data Science and Engineering',
#    'type': 'Department',
#    'institute': 'IISER Bhopal',
#    'hod': 'Dr. Tanmay Basu'},
#   {'type': 'Department',
#    'id': 'DSE',
#    'name': 'Department of Data Science and Engineering',
#    'institute': 'IISER Bhopal',
#    'hod': 'Dr. Tanmay Basu'},
#   {'name': 'Director Name',
#    'type': 'Faculty',
#    'id': 'Director Name',
#    'email': 'director@iiserb.ac.in',
#    'department': 'IISER Bhopal',
#    'position': 'Director'},
#   {'type': 'Student',
#    'name': 'BS-MS 5th Year',
#    'department': 'DSE',
#    'institute': 'IISER Bhopal',
#    'id': 'BS-MS 5th Year'},
#   {'type': 'Student',
#    'name': 'BS-MS Majors (3rd Year)',
#    'department': 'DSE',
#    'institute': 'IISER Bhopal',
#    'id': 'BS-MS Majors (3rd Year)'},
#   {'type': 'Student',
#    'name': 'BS-MS Majors (4th Year)',
#    'department': 'DSE',
#    'institute': 'IISER Bhopal',
#    'id': 'BS-MS Majors (4th Year)'},
#   {'type': 'PhD', 'name': 'PhD', 'id': 'PhD'},
#   {'type': 'Student',
#    'name': 'Alumni',
#    'department': 'DSE',
#    'institute': 'IISER Bhopal',
#    'id': 'Alumni'},
#   {'name': 'PhD', 'type': 'Program', 'id': '/phd'},
#   {'name': 'BS-MS 5th Year', 'type': 'Program', 'id': '/bs-ms-5th-year'},
#   {'name': 'BS-MS Majors (3rd Year)',
#    'type': 'Program',
#    'id': '/bs-ms-majors-3rd-year'},
#   {'name': 'BS-MS Majors (4th Year)',
#    'type': 'Program',
#    'id': '/bs-ms-majors-4th-year'},
#   {'name': 'Alumni', 'type': 'Group', 'id': '/alumni'},
#   {'name': 'BS-MS Majors (3rd Year)',
#    'type': 'BS | MS | PhD | PostDoc',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'bs-ms-majors-3rd-year'},
#   {'name': 'BS-MS Majors (4th Year)',
#    'type': 'BS | MS | PhD | PostDoc',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'bs-ms-majors-4th-year'},
#   {'name': 'BS-MS 5th Year',
#    'type': 'BS | MS | PhD | PostDoc',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'bs-ms-5th-year'},
#   {'name': 'Alumni',
#    'type': 'BS | MS | PhD | PostDoc',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'alumni'},
#   {'name': 'PhD',
#    'type': 'BS | MS | PhD | PostDoc',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'phd'},
#   {'name': 'Office',
#    'type': 'Office',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'office'},
#   {'name': 'Department Homepage',
#    'type': 'Website',
#    'id': 'department-homepage',
#    'url': 'https://dse.iiserb.ac.in'},
#   {'name': 'IISER Bhopal', 'type': 'Institute', 'id': 'iiser-bhopal'},
#   {'name': 'Dr. Tanmay Basu',
#    'type': 'Faculty',
#    'id': 'dr-tanmay-basu',
#    'email': 'hod_dse@iiserb.ac.in',
#    'department': 'dse-iiserb',
#    'position': 'Head'},
#   {'name': 'hod_dse@iiserb.ac.in',
#    'type': 'Faculty',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'hod-dse-iiserb-ac-in'},
#   {'name': 'office_dse@iiserb.ac.in',
#    'type': 'Faculty',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': 'office-dse-iiserb-ac-in'},
#   {'name': '3rd Year Students',
#    'type': 'Student',
#    'department': 'Department Homepage',
#    'institute': 'IISER Bhopal',
#    'id': '3rd-year-students'},
#   {'type': 'Department',
#    'id': 'Department of Data Science and Engineering',
#    'name': 'Department of Data Science and Engineering',
#    'institute': 'IISER Bhopal',
#    'hod': 'Dr. Tanmay Basu'},
#   {'name': 'Department of Data Science and Engineering',
#    'id': 'Department Homepage',
#    'type': 'Department',
#    'institute': 'IISER Bhopal',
#    'hod': 'Dr. Tanmay Basu'},
#   {'name': 'Tanishq Sharma',
#    'id': 'Tanishq Sharma',
#    'type': 'Student',
#    'roll_no': '22349',
#    'email': 'tanishq22@iiserb.ac.in',
#    'department': 'Department Homepage',
#    'supervisor': 'NA'},
#   {'id': 'P S Rishi',
#    'name': 'P S Rishi',
#    'type': 'BS',
#    'roll_no': '22229',
#    'email': 'rishi22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/sarthak-srivastava',
#    'github': 'https://www.linkedin.com/in/sarthak-srivastava',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Sarthak Srivastava',
#    'name': 'Sarthak Srivastava',
#    'type': 'BS',
#    'roll_no': '21240',
#    'email': 'sarthak21@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/sarthak-srivastava',
#    'github': 'https://www.linkedin.com/in/sarthak-srivastava',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Vishal Bharti',
#    'name': 'Vishal Bharti',
#    'type': 'Student',
#    'roll_no': '21310',
#    'email': 'vishal21@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/vishalbhartiofficial/',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Darshana Srivathsan',
#    'name': 'Darshana Srivathsan',
#    'type': 'Student',
#    'roll_no': '22001',
#    'email': 'darshana22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://github.com/dsb4u',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Devesh Lalit Fegade',
#    'name': 'Devesh Lalit Fegade',
#    'type': 'Student',
#    'roll_no': '22104',
#    'email': 'devesh22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/devesh-fegade-a661422b3/',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Swatish Jena',
#    'name': 'Swatish Jena',
#    'type': 'Student',
#    'roll_no': '21376',
#    'email': 'swatish21@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://github.com/swatish434',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Rudra Prasad Tarai',
#    'name': 'Rudra Prasad Tarai',
#    'type': 'Student',
#    'roll_no': '22269',
#    'email': 'rudra22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://github.com/Rudra-prasad-tarai',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Jiya Sinha',
#    'name': 'Jiya Sinha',
#    'type': 'Student',
#    'roll_no': '22161',
#    'email': 'jiya22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://github.com/sinhajiya',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Aditya Dandhare',
#    'name': 'Aditya Dandhare',
#    'type': 'Student',
#    'roll_no': '22019',
#    'email': 'aditya22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/aditya-dandhare-377b09294/',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Anirudha Patil',
#    'name': 'Anirudha Patil',
#    'type': 'Student',
#    'roll_no': '22234',
#    'email': 'anirudha22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/anirudha-patil-135447255',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Pratyaksh Patel',
#    'name': 'Pratyaksh Patel',
#    'type': 'Student',
#    'roll_no': '22233',
#    'email': 'pratyaksh22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Soumyadeep Gope',
#    'name': 'Soumyadeep Gope',
#    'type': 'Student',
#    'roll_no': '22329',
#    'email': 'soumyadeepg22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Shailesh kachhi',
#    'name': 'Shailesh kachhi',
#    'type': 'Student',
#    'roll_no': '22290',
#    'email': 'shailesh22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://github.com/Shailesh22290',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Jay Bharambe',
#    'name': 'Jay Bharambe',
#    'type': 'Student',
#    'roll_no': '22159',
#    'email': 'jayb22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'https://github.com/jayb71',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Gudala Rushi Kesava Reddy',
#    'name': 'Gudala Rushi Kesava Reddy',
#    'type': 'Student',
#    'roll_no': '22135',
#    'email': 'gudala22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'GitHub/LinkedIn',
#    'github': 'GitHub/LinkedIn',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '2@iiserb.ac.in',
#    'name': 'Ramanaboyina Joel Silas',
#    'type': 'NA',
#    'roll_no': '22255',
#    'email': 'ramanaboyina22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/ramanaboyina-joel-silas-974099325',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Divyansh Pathak',
#    'name': 'Divyansh Pathak',
#    'type': 'BS',
#    'roll_no': '22113',
#    'email': 'divyansh22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://github.com/tituatgithub',
#    'github': 'https://github.com/tituatgithub',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Shrey Srivastava',
#    'name': 'Shrey Srivastava',
#    'type': 'BS',
#    'roll_no': '22303',
#    'email': 'shrey22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/shrey-srivastava-829662248/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Harsh Shukla',
#    'name': 'Harsh Shukla',
#    'type': 'BS',
#    'roll_no': '22140',
#    'email': 'harshs22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'http://www.linkedin.com/in/harsh-shukla-b641ab2a4',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Saptarshi Halder',
#    'name': 'Saptarshi Halder',
#    'type': 'BS',
#    'roll_no': '22283',
#    'email': 'saptarshi22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/saptarshihalder',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Rushikesh Bhosale',
#    'name': 'Rushikesh Bhosale',
#    'type': 'BS',
#    'roll_no': '22078',
#    'email': 'bhosale22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/rushikesh-bhosale-77b11a2b6?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Manjul Chaturvedi',
#    'name': 'Manjul Chaturvedi',
#    'type': 'BS',
#    'roll_no': '22194',
#    'email': 'manjul22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/manjul-chaturvedi-949927272/=',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Aman Pasi',
#    'name': 'Aman Pasi',
#    'type': 'BS',
#    'roll_no': '22034',
#    'email': 'amanp22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/aman-pasi-5b8a35266/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Bhaisare Rohit Bhaurao',
#    'name': 'Bhaisare Rohit Bhaurao',
#    'type': 'BS',
#    'roll_no': '21076',
#    'email': 'bhaisare21@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://github.com/Rohit29B',
#    'github': 'https://github.com/Rohit29B',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Manish Kumar Meena',
#    'name': 'Manish Kumar Meena',
#    'type': 'BS',
#    'roll_no': '21162',
#    'email': 'manishk21@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://github.com/Manish03M target=',
#    'github': 'https://github.com/Manish03M target=',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Saurabh Shinde',
#    'name': 'Saurabh Shinde',
#    'type': 'BS',
#    'roll_no': '22296',
#    'email': 'shinde22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/saurabh-shinde-b2451824a',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Nandhana K S',
#    'name': 'Nandhana K S',
#    'type': 'BS',
#    'roll_no': '22215',
#    'email': 'nandhana22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/nandhana-k-s-a39028261)',
#    'github': 'Github/Linkedin',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Sakshi Tiwari',
#    'name': 'Sakshi Tiwari',
#    'type': 'BS',
#    'roll_no': '22275',
#    'email': 'sakshi22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/sakshi-tiwari-921253257',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'akshi22',
#    'name': 'Sakshi Tiwari',
#    'type': 'BS',
#    'roll_no': 'NA',
#    'email': 'akshi22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/sakshi-tiwari-921253257',
#    'github': 'https://www.linkedin.com/in/sakshi-tiwari-921253257',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Shreyash Gaikwad',
#    'name': 'Shreyash Gaikwad',
#    'type': 'BS',
#    'roll_no': '22125',
#    'email': 'gaikwad22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Ashish Raj',
#    'name': 'Ashish Raj',
#    'type': 'BS',
#    'roll_no': '22061',
#    'email': 'ashishraj22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/ashish-raj-838330266',
#    'github': 'https://www.linkedin.com/in/ashish-raj-838330266',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Rashi Bhardo',
#    'name': 'Rashi Bhardo',
#    'type': 'BS',
#    'roll_no': '22256',
#    'email': 'rashi22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/rashi-bhardo',
#    'github': 'https://github.com/bhardor',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Peddinti Hari Krishna',
#    'name': 'Peddinti Hari Krishna',
#    'type': 'BS',
#    'roll_no': '22236',
#    'email': 'peddinti22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/hari-krishna-peddinti-58975222a',
#    'github': 'https://www.linkedin.com/in/hari-krishna-peddinti-58975222a',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Chaitanya Shinde',
#    'name': 'Chaitanya Shinde',
#    'type': 'BS',
#    'roll_no': '22085',
#    'email': 'chaitanya22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/chaitanya-shinde-476429136',
#    'github': 'https://www.linkedin.com/in/chaitanya-shinde-476429136',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Dev Raj Singh',
#    'name': 'Dev Raj Singh',
#    'type': 'BS',
#    'roll_no': '22102',
#    'email': 'devraj22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/me?trk=p_mwlite_feed-secondary_nav',
#    'github': 'https://www.linkedin.com/me?trk=p_mwlite_feed-secondary_nav',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'HIBA K T',
#    'name': 'HIBA K T',
#    'type': 'BS',
#    'roll_no': '22146',
#    'email': 'hiba22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/hiba-k-t-10182b317',
#    'github': 'https://www.linkedin.com/in/hiba-k-t-10182b317',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Vivek Kumar',
#    'name': 'Vivek Kumar',
#    'type': 'BS',
#    'roll_no': '22373',
#    'email': 'vivekk22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://github.com/VivekSinghRathore7',
#    'github': 'https://github.com/VivekSinghRathore7',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Nayana Barai',
#    'name': 'Nayana Barai',
#    'type': 'BS',
#    'roll_no': '21182',
#    'email': 'nayana21@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/nayana-barai-617a13259',
#    'github': 'www.linkedin.com/in/nayana-barai-617a13259',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Arpan Jain',
#    'name': 'Arpan Jain',
#    'type': 'BS',
#    'roll_no': '22056',
#    'email': 'arpan22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/arpan-jain-iiserb',
#    'github': 'https://www.linkedin.com/in/arpan-jain-iiserb',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'Madhav B panicker',
#    'name': 'Madhav B panicker',
#    'type': 'BS',
#    'roll_no': '22187',
#    'email': 'madhav22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://github.com/madhavbpanicker',
#    'github': 'https://github.com/madhavbpanicker',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': 'A',
#    'name': 'Ramanaboyina Joel Silas',
#    'type': 'BS',
#    'roll_no': 'NA',
#    'email': 'NA',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/ramanaboyina-joel-silas-974099325?utm_source=share&utm_campaign=share_via&utm_content=profile&utm_medium=android_app',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22061',
#    'name': 'Ashish Raj',
#    'type': 'BS',
#    'roll_no': '22061',
#    'email': 'ashishraj22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/ashish-raj-838330266/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22256',
#    'name': 'Rashi Bhardo',
#    'type': 'BS',
#    'roll_no': '22256',
#    'email': 'rashi22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/bhardor',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22236',
#    'name': 'Peddinti Hari Krishna',
#    'type': 'BS',
#    'roll_no': '22236',
#    'email': 'peddinti22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/hari-krishna-peddinti-58975222a/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22085',
#    'name': 'Chaitanya Shinde',
#    'type': 'BS',
#    'roll_no': '22085',
#    'email': 'chaitanya22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/chaitanya-shinde-476429136/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22102',
#    'name': 'Dev Raj Singh',
#    'type': 'BS',
#    'roll_no': '22102',
#    'email': 'devraj22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/me?trk=p_mwlite_feed-secondary_nav',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22146',
#    'name': 'HIBA K T',
#    'type': 'BS',
#    'roll_no': '22146',
#    'email': 'hiba22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/hiba-k-t-10182b317/',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22373',
#    'name': 'Vivek Kumar',
#    'type': 'BS',
#    'roll_no': '22373',
#    'email': 'vivekk22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/VivekSinghRathore7',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '21182',
#    'name': 'Nayana Barai',
#    'type': 'BS',
#    'roll_no': '21182',
#    'email': 'nayana21@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'www.linkedin.com/in/nayana-barai-617a13259',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22056',
#    'name': 'Arpan Jain',
#    'type': 'BS',
#    'roll_no': '22056',
#    'email': 'arpan22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'https://www.linkedin.com/in/arpan-jain-iiserb',
#    'github': 'NA',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'id': '22187',
#    'name': 'Madhav B panicker',
#    'type': 'BS',
#    'roll_no': '22187',
#    'email': 'madhav22@iiserb.ac.in',
#    'department': 'NA',
#    'linkedin': 'NA',
#    'github': 'https://github.com/madhavbpanicker',
#    'research_group': 'NA',
#    'guide': 'NA'},
#   {'type': 'BS-MS',
#    'id': '4th Year Students',
#    'name': '4th Year Students',
#    'department': 'DSE'},
#   {'name': 'office_dse@iiserb.ac.in',
#    'type': 'Email',
#    'id': 'office_dse@iiserb.ac.in',
#    'department': 'DSE'},
#   {'name': 'Department Homepage',
#    'type': 'Website',
#    'id': 'https://dse.iiserb.ac.in',
#    'department': 'DSE'},
#   {'type': 'Student',
#    'name': 'DSE Students IISER Bhopal',
#    'department': 'DSE',
#    'institute': 'IISER Bhopal',
#    'id': 'DSE Students IISER Bhopal'},
#   {'id': 'Aryan Mishra',
#    'name': 'Aryan Mishra',
#    'type': 'Student',
#    'roll_no': '21056',
#    'email': 'aryan21@iiserb.ac.in',
#    'department': 'Data Science and Engineering',
# ...
#   {'relation': 'belongsTo', 'from': 'parinita', 'to': 'department ID'},
#   {'relation': 'guidedBy', 'from': 'parinita', 'to': 'Dr. Vinod K. Kurmi'},
#   {'relation': 'belongsTo', 'from': 'vishesh', 'to': 'department ID'},
#   {'relation': 'guidedBy', 'from': 'vishesh', 'to': 'Dr. Akshay Agarwal'},
#   {'relation': 'belongsTo', 'from': 'pyarelal', 'to': 'department ID'},
#   {'relation': 'guidedBy', 'from': 'pyarelal', 'to': 'Dr. Vaibhav Kumar'},
#   {'relation': 'belongsTo', 'from': 'rajeev', 'to': 'department ID'},
#   {'relation': 'guidedBy', 'from': 'rajeev', 'to': 'Dr. Vinod k. Kurmi'},
#   {'relation': 'belongsTo', 'from': 'debajyoti', 'to': 'department ID'},
#   {'relation': 'heads', 'from': 'Faculty', 'to': 'Department'},
#   {'relation': 'guidedBy', 'from': 'Student', 'to': 'Faculty'},
#   {'relation': 'belongsTo', 'from': 'Student', 'to': 'Department'},
#   {'relation': 'memberOf', 'from': 'Student', 'to': 'ResearchGroup'},
#   {'relation': 'partOf', 'from': 'Department', 'to': 'Institute'},
#   {'relation': 'heads', 'from': 'Faculty', 'to': 'ResearchGroup'},
#   {'relation': 'partOf',
#    'from': 'Department of Computer Science',
#    'to': 'Institute ID'},
#   {'relation': 'heads', 'from': 'Faculty ID', 'to': 'GeoAI4Cities Lab'},
#   {'relation': 'heads', 'from': 'Faculty ID', 'to': 'ISHA Lab'},
#   {'relation': 'partOf',
#    'from': 'Department of Biological Sciences',
#    'to': 'Institute ID'},
#   {'relation': 'heads', 'from': 'Faculty ID', 'to': 'BDS Lab'},
#   {'relation': 'belongsTo',
#    'from': 'Faculty ID',
#    'to': 'Department of Computer Science'},
#   {'relation': 'belongsTo',
#    'from': 'Faculty ID',
#    'to': 'Department of Biological Sciences'},
#   {'relation': 'partOf', 'from': 'bbmed0', 'to': 'Computer Science'},
#   {'relation': 'heads', 'from': 'Faculty ID', 'to': 'bbmed0'},
#   {'relation': 'partOf', 'from': 'visdom', 'to': 'Computer Science'},
#   {'relation': 'heads', 'from': 'Faculty ID', 'to': 'visdom'},
#   {'relation': 'partOf',
#    'from': 'trustworthy_biometravision_lab',
#    'to': 'Computer Science'},
#   {'relation': 'heads',
#    'from': 'Faculty ID',
#    'to': 'trustworthy_biometravision_lab'},
#   {'relation': 'partOf', 'from': 'Computer Science', 'to': 'iiserb'},
#   {'relation': 'partOf', 'from': 'computer_science', 'to': 'iiserb'},
#   {'relation': 'heads', 'from': 'Faculty ID', 'to': 'computer_science'},
#   {'relation': 'belongsTo', 'from': 'SoDAL Lab', 'to': 'IISER Bhopal'},
#   {'relation': 'heads', 'from': 'Akash Anil', 'to': 'SoDAL Lab'},
#   {'relation': 'belongsTo',
#    'from': 'Robotic Perception and Embodied Intelligence Lab',
#    'to': 'IISER Bhopal'},
#   {'relation': 'heads',
#    'from': 'Sundaram Muthu',
#    'to': 'Robotic Perception and Embodied Intelligence Lab'},
#   {'relation': 'partOf',
#    'from': 'IISER Bhopal',
#    'to': 'Indian Institute of Science'},
#   {'relation': 'belongsTo', 'from': 'Student_1', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_1', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_2', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_2', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_3', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_3', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_4', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_4', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_5', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_5', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_6', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_6', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_7', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_7', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_8', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_8', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_9', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_9', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_10', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_10', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_11', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_11', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_12', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_12', 'to': 'ResearchGroup_1'},
#   {'relation': 'belongsTo', 'from': 'Student_13', 'to': 'Department_1'},
#   {'relation': 'memberOf', 'from': 'Student_13', 'to': 'ResearchGroup_1'},
#   {'relation': 'heads',
#    'from': 'Dr. Tanmay Basu',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'partOf',
#    'from': 'Data Science and Engineering',
#    'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'DSE', 'to': 'IISER Bhopal'},
#   {'relation': 'heads', 'from': 'Dr. Tanmay Basu', 'to': 'DSE'},
#   {'relation': 'partOf', 'from': 'IISER Bhopal', 'to': 'Director Name'},
#   {'relation': 'memberOf',
#    'from': 'BS-MS 5th Year',
#    'to': 'Research Group ID'},
#   {'relation': 'guidedBy', 'from': 'BS-MS 5th Year', 'to': 'Faculty ID'},
#   {'relation': 'memberOf',
#    'from': 'BS-MS Majors (3rd Year)',
#    'to': 'Research Group ID'},
#   {'relation': 'guidedBy',
#    'from': 'BS-MS Majors (3rd Year)',
#    'to': 'Faculty ID'},
#   {'relation': 'memberOf',
#    'from': 'BS-MS Majors (4th Year)',
#    'to': 'Research Group ID'},
#   {'relation': 'guidedBy',
#    'from': 'BS-MS Majors (4th Year)',
#    'to': 'Faculty ID'},
#   {'relation': 'memberOf', 'from': 'PhD', 'to': 'Research Group ID'},
#   {'relation': 'guidedBy', 'from': 'PhD', 'to': 'Faculty ID'},
#   {'relation': 'memberOf', 'from': 'Alumni', 'to': 'Research Group ID'},
#   {'relation': 'guidedBy', 'from': 'Alumni', 'to': 'Faculty ID'},
#   {'relation': 'partOf', 'from': 'IISER Bhopal', 'to': 'Department'},
#   {'relation': 'heads', 'from': 'Dr. Tanmay Basu', 'to': 'Department'},
#   {'relation': 'guidedBy', 'from': 'Student', 'to': 'Dr. Tanmay Basu'},
#   {'relation': 'memberOf', 'from': 'Student', 'to': 'Research Group'},
#   {'relation': 'belongsTo', 'from': '/phd', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': '/phd', 'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'partOf',
#    'from': '/bs-ms-5th-year',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'partOf',
#    'from': '/bs-ms-majors-3rd-year',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'partOf',
#    'from': '/bs-ms-majors-4th-year',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'memberOf',
#    'from': '/alumni',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo',
#    'from': 'bs-ms-majors-3rd-year',
#    'to': 'Department Homepage'},
#   {'relation': 'partOf', 'from': 'Department Homepage', 'to': 'IISER Bhopal'},
#   {'relation': 'belongsTo',
#    'from': 'bs-ms-majors-4th-year',
#    'to': 'Department Homepage'},
#   {'relation': 'belongsTo',
#    'from': 'bs-ms-5th-year',
#    'to': 'Department Homepage'},
#   {'relation': 'belongsTo', 'from': 'alumni', 'to': 'Department Homepage'},
#   {'relation': 'belongsTo', 'from': 'phd', 'to': 'Department Homepage'},
#   {'relation': 'belongsTo', 'from': 'office', 'to': 'Department Homepage'},
#   {'relation': 'partOf', 'from': 'department-homepage', 'to': 'IISER Bhopal'},
#   {'relation': 'heads', 'from': 'dr-tanmay-basu', 'to': 'Department Homepage'},
#   {'relation': 'heads',
#    'from': 'hod-dse-iiserb-ac-in',
#    'to': 'Department Homepage'},
#   {'relation': 'heads',
#    'from': 'office-dse-iiserb-ac-in',
#    'to': 'Department Homepage'},
#   {'relation': 'memberOf',
#    'from': '3rd-year-students',
#    'to': 'Department Homepage'},
#   {'relation': 'partOf',
#    'from': 'IISER Bhopal',
#    'to': 'Department of Data Science and Engineering'},
#   {'relation': 'belongsTo',
#    'from': 'Department of Data Science and Engineering',
#    'to': 'IISER Bhopal'},
#   {'relation': 'heads',
#    'from': 'Dr. Tanmay Basu',
#    'to': 'Department of Data Science and Engineering'},
#   {'relation': 'guidedBy', 'from': 'Dr. Tanmay Basu', 'to': 'Dr. Tanmay Basu'},
#   {'relation': 'heads',
#    'from': 'Dr. Tanmay Basu',
#    'to': 'Department Homepage'},
#   {'relation': 'belongsTo',
#    'from': 'Tanishq Sharma',
#    'to': 'Department Homepage'},
#   {'relation': 'heads', 'from': 'P S Rishi', 'to': 'NA'},
#   {'relation': 'guidedBy', 'from': 'Sarthak Srivastava', 'to': 'P S Rishi'},
#   {'relation': 'memberOf', 'from': '4th Year Students', 'to': 'DSE'},
#   {'relation': 'belongsTo', 'from': 'DSE', 'to': 'IISER Bhopal'},
#   {'relation': 'memberOf', 'from': 'DSE Students IISER Bhopal', 'to': 'DSE'},
#   {'relation': 'memberOf', 'from': 'PhD', 'to': 'DSE'},
#   {'relation': 'memberOf', 'from': 'BS-MS 5th Year', 'to': 'DSE'},
#   {'relation': 'memberOf', 'from': 'BS-MS Majors (3rd Year)', 'to': 'DSE'},
#   {'relation': 'memberOf', 'from': 'BS-MS Majors (4th Year)', 'to': 'DSE'},
#   {'relation': 'memberOf', 'from': 'Alumni', 'to': 'DSE'},
#   {'relation': 'partOf', 'from': 'PhD', 'to': 'DSE'},
#   {'relation': 'partOf', 'from': 'BS-MS 5th Year', 'to': 'DSE'},
#   {'relation': 'partOf', 'from': 'BS-MS Majors (3rd Year)', 'to': 'DSE'},
#   {'relation': 'partOf', 'from': 'BS-MS Majors (4th Year)', 'to': 'DSE'},
#   {'relation': 'partOf', 'from': 'Alumni', 'to': 'DSE'},
#   {'relation': 'belongsTo', 'from': 'office_dse@iiserb.ac.in', 'to': 'DSE'},
#   {'relation': 'belongsTo', 'from': 'Department Homepage', 'to': 'DSE'},
#   {'relation': 'belongsTo', 'from': 'DSE Students IISER Bhopal', 'to': 'DSE'},
#   {'relation': 'guidedBy', 'from': 'PhD', 'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo', 'from': 'BS-MS 5th Year', 'to': 'DSE'},
#   {'relation': 'guidedBy',
#    'from': 'BS-MS 5th Year',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo', 'from': 'BS-MS Majors (3rd Year)', 'to': 'DSE'},
#   {'relation': 'guidedBy',
#    'from': 'BS-MS Majors (3rd Year)',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo', 'from': 'BS-MS Majors (4th Year)', 'to': 'DSE'},
#   {'relation': 'guidedBy',
#    'from': 'BS-MS Majors (4th Year)',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo', 'from': 'Alumni', 'to': 'DSE'},
#   {'relation': 'guidedBy',
#    'from': 'Alumni',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'heads', 'from': 'DSE', 'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'heads', 'from': 'DSE', 'to': 'BS-MS 5th Year'},
#   {'relation': 'heads', 'from': 'DSE', 'to': 'BS-MS Majors (3rd Year)'},
#   {'relation': 'heads', 'from': 'DSE', 'to': 'BS-MS Majors (4th Year)'},
#   {'relation': 'heads', 'from': 'DSE', 'to': 'Alumni'},
#   {'relation': 'belongsTo',
#    'from': 'Department of Data Science and Engineering',
#    'to': 'Institute'},
#   {'relation': 'heads',
#    'from': 'Department of Data Science and Engineering',
#    'to': 'Dr. Tanmay Basu'},
#   {'relation': 'partOf',
#    'from': 'Department of Data Science and Engineering',
#    'to': 'IISER Bhopal'},
#   {'relation': 'heads',
#    'from': 'Data Science and Engineering',
#    'to': 'Dr. Tanmay Basu'},
#   {'relation': 'guidedBy', 'from': 'Aryan Mishra', 'to': 'Dr. Akash Anil'},
#   {'relation': 'memberOf',
#    'from': 'Aryan Mishra',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'guidedBy',
#    'from': 'Prasanna D Kharode',
#    'to': 'Dr. Akash Anil'},
#   {'relation': 'memberOf',
#    'from': 'Prasanna D Kharode',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'guidedBy', 'from': 'Debasmita Panda', 'to': 'Dr. Akash Anil'},
#   {'relation': 'memberOf',
#    'from': 'Debasmita Panda',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'guidedBy',
#    'from': 'Sharayu Borade',
#    'to': 'Dr. Akshay Agarwal'},
#   {'relation': 'memberOf',
#    'from': 'Sharayu Borade',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'guidedBy', 'from': 'Gurleen Kaur', 'to': 'Dr. Akshay Agarwal'},
#   {'relation': 'memberOf',
#    'from': 'Gurleen Kaur',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'guidedBy',
#    'from': 'Khushi Chaudhari',
#    'to': 'Dr. Akshay Agarwal'},
#   {'relation': 'memberOf',
#    'from': 'Khushi Chaudhari',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'guidedBy',
#    'from': 'Gargi Surendra Yeole',
#    'to': 'Dr. Akshay Agarwal'},
#   {'relation': 'memberOf',
#    'from': 'Gargi Surendra Yeole',
#    'to': 'Data Science and Engineering'},
#   {'relation': 'heads',
#    'from': 'Data Science and Engineering',
#    'to': 'Dr. Akash Anil'},
#   {'relation': 'heads',
#    'from': 'Data Science and Engineering',
#    'to': 'Dr. Akshay Agarwal'},
#   {'relation': 'belongsTo', 'from': 'Shivam Chopra', 'to': 'DSE'},
#   {'relation': 'guidedBy', 'from': 'Shivam Chopra', 'to': 'Dr. Vaibhav Kumar'},
#   {'relation': 'belongsTo', 'from': 'Suchetan G U', 'to': 'DSE'},
#   {'relation': 'guidedBy', 'from': 'Suchetan G U', 'to': 'Dr. Vaibhav Kumar'},
#   {'relation': 'belongsTo', 'from': 'Porus Vaid', 'to': 'DSE'},
#   {'relation': 'guidedBy', 'from': 'Porus Vaid', 'to': 'Dr. Vaibhav Kumar'},
#   {'relation': 'belongsTo', 'from': 'Aditya Kumar Singh', 'to': 'DSE'},
#   {'relation': 'guidedBy',
#    'from': 'Aditya Kumar Singh',
#    'to': 'Dr. Vinod K Kurmi'},
#   {'relation': 'belongsTo', 'from': 'Aditya Manoj', 'to': 'DSE'},
#   {'relation': 'guidedBy', 'from': 'Aditya Manoj', 'to': 'Dr. Sundaram Muthu'},
#   {'relation': 'heads', 'from': 'Dr. Vaibhav Kumar', 'to': 'DSE'},
#   {'relation': 'heads', 'from': 'Dr. Vinod K Kurmi', 'to': 'DSE'},
#   {'relation': 'heads', 'from': 'Dr. Sundaram Muthu', 'to': 'DSE'},
#   {'relation': 'belongsTo', 'from': 'SE Students IISER Bhopal', 'to': 'DSE'},
#   {'relation': 'guidedBy',
#    'from': 'SE Students IISER Bhopal',
#    'to': 'Dr. Tanmay Basu'},
#   {'relation': 'memberOf', 'from': 'SE Students IISER Bhopal', 'to': 'DSE'},
#   {'relation': 'partOf', 'from': 'Dr. Tanmay Basu', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'dse-iiserb', 'to': 'iiserb'},
#   {'relation': 'heads', 'from': 'Dr. Tanmay Basu', 'to': 'dse-iiserb'},
#   {'relation': 'heads', 'from': 'dr-tanmay-basu', 'to': 'dse-iiserb'},
#   {'relation': 'belongsTo', 'from': 'office-dse', 'to': 'dse-iiserb'},
#   {'relation': 'belongsTo', 'from': 'department-homepage', 'to': 'dse-iiserb'},
#   {'relation': 'belongsTo',
#    'from': 'S Majors',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo',
#    'from': 'BS-MS Majors',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo',
#    'from': 'Alumni',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'partOf',
#    'from': 'DSE Students IISER Bhopal',
#    'to': 'IISER Bhopal'},
#   {'relation': 'belongsTo', 'from': 'PhD', 'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo',
#    'from': 'BS-MS 5th Year',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo',
#    'from': 'BS-MS Majors (3rd Year)',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo',
#    'from': 'BS-MS Majors (4th Year)',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'belongsTo', 'from': 'More', 'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'memberOf',
#    'from': 'office_dse@iiserb.ac.in',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'memberOf',
#    'from': 'Department Homepage',
#    'to': 'DSE Students IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'Department', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'BS-MS 5th Year', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf',
#    'from': 'BS-MS Majors (3rd Year)',
#    'to': 'IISER Bhopal'},
#   {'relation': 'partOf',
#    'from': 'BS-MS Majors (4th Year)',
#    'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'Alumni', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'PhD', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'MS Students', 'to': 'IISER Bhopal'},
#   {'relation': 'locatedIn', 'from': 'Office', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'IISER Bhopal', 'to': 'IISER Bhopal'},
#   {'relation': 'partOf', 'from': 'dse', 'to': 'iiserb'},
#   {'relation': 'heads', 'from': 'Tanmay Basu', 'to': 'dse'}]}

# %%
import networkx as nx
from pyvis.network import Network

# Create PyVis network
net = Network(height="800px", width="100%", directed=True, bgcolor="#ffffff", font_color="black")

# Use a physics-enabled layout
net.barnes_hut()

# Initialize NetworkX graph
G = nx.DiGraph()

# Add nodes
for node in data["nodes"]:
    node_id = node["id"]
    title = f"""
    <b>{node.get('name','')}</b><br>
    Email: {node.get('email','')}<br>
    Dept: {node.get('department','')}<br>
    Position: {node.get('position','')}<br>
    Homepage: {node.get('homepage','')}
    """
    G.add_node(node_id, title=title, label=node.get("name", node_id))

# Add edges
for e in data["edges"]:
    G.add_edge(e["from"], e["to"], title=e["relation"], label=e["relation"])

# Build graph
net.from_nx(G)

from IPython.core.display import HTML

HTML(open("iiserb_graph.html", "r").read())
# Out:
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script src="lib/bindings/utils.js"></script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 800px;
#                  background-color: #ffffff;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#              #loadingBar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width: 100%;
#                  height: 800px;
#                  background-color:rgba(200,200,200,0.8);
#                  -webkit-transition: all 0.5s ease;
#                  -moz-transition: all 0.5s ease;
#                  -ms-transition: all 0.5s ease;
#                  -o-transition: all 0.5s ease;
#                  transition: all 0.5s ease;
#                  opacity:1;
#              }
#
#              #bar {
#                  position:absolute;
#                  top:0px;
#                  left:0px;
#                  width:20px;
#                  height:20px;
#                  margin:auto auto auto auto;
#                  border-radius:11px;
#                  border:2px solid rgba(30,30,30,0.05);
#                  background: rgb(0, 173, 246); /* Old browsers */
#                  box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#              }
#
#              #border {
#                  position:absolute;
#                  top:10px;
#                  left:10px;
#                  width:500px;
#                  height:23px;
#                  margin:auto auto auto auto;
#                  box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#                  border-radius:10px;
#              }
#
#              #text {
#                  position:absolute;
#                  top:8px;
#                  left:530px;
#                  width:30px;
#                  height:50px;
#                  margin:auto auto auto auto;
#                  font-size:22px;
#                  color: #000000;
#              }
#
#              div.outerBorder {
#                  position:relative;
#                  top:400px;
#                  width:600px;
#                  height:44px;
#                  margin:auto auto auto auto;
#                  border:8px solid rgba(0,0,0,0.1);
#                  background: rgb(252,252,252); /* Old browsers */
#                  background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#                  background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#                  background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#                  background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#                  background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#                  background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#                  filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#                  border-radius:72px;
#                  box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#              }
#
#
#
#
#
#         </style>
#     </head>
#
#
#     <body>
#         <div class="card" style="width: 100%">
#
#
#             <div id="mynetwork" class="card-body"></div>
#         </div>
#
#
#             <div id="loadingBar">
#               <div class="outerBorder">
#                 <div id="text">0%</div>
#                 <div id="border">
#                   <div id="bar"></div>
#                 </div>
#               </div>
#             </div>
#
#
#
#         <script type="text/javascript">
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : '',
#                   property : '',
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById('mynetwork');
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{"color": "#97c2fc", "font": {"color": "black"}, "id": "vaibhav", "label": "Vaibhav Kumar", "shape": "dot", "size": 10, "title": "\n    \u003cb\u003eVaibhav Kumar\u003c/b\u003e\u003cbr\u003e\n    Email: vaibhav@iiserb.ac.in\u003cbr\u003e\n    Dept: DSE\u003cbr\u003e\n    Position: Assistant Professor\u003cbr\u003e\n    Homepage: https://sites.google.com/view/vaibhavkumar1/home\n    "}, {"color": "#97c2fc", "font": {"color": "black"}, "id": "DSE", "label": "Department of Data Science and Engineering", "shape": "dot", "size": 10, "title": "\n    \u003cb\u003eDepartment of Data Science and Engineering\u003c/b\u003e\u003cbr\u003e\n    Email: \u003cbr\u003e\n    Dept: \u003cbr\u003e\n    Position: \u003cbr\u003e\n    Homepage: \n    "}, {"color": "#97c2fc", "font": {"color": "black"}, "id": "tanmay", "label": "Tanmay Basu", "shape": "dot", "size": 10, "title": "\n    \u003cb\u003eTanmay Basu\u003c/b\u003e\u003cbr\u003e\n    Email: tanmay@iiserb.ac.in\u003cbr\u003e\n    Dept: DSE\u003cbr\u003e\n    Position: Assistant Professor\u003cbr\u003e\n    Homepage: https://sites.google.com/view/tanmaybasu/\n    "}, {"color": "#97c2fc", "font": {"color": "black"}, "id": "jasabanta", "label": "Jasabanta Patro", "shape": "dot", "size": 10, "title": "\n    \u003cb\u003eJasabanta Patro\u003c/b\u003e\u003cbr\u003e\n    Email: jpatro@iiserb.ac.in\u003cbr\u003e\n    Dept: DSE\u003cbr\u003e\n    Position: Assistant Professor\u003cbr\u003e\n    Homepage: https://sites.google.com/view/jpatro/home\n    "}, {"color": "#97c2fc", "font": {"color": "black"}, "id": "vinod", "label": "Vinod K Kurmi", "shape": "dot", "size": 10, "title": "\n    \u003cb\u003eVinod K Kurmi\u003c/b\u003e\u003cbr\u003e\n    Email: vinodkk@iiserb.ac.in\u003cbr\u003e\n    Dept: DSE\u003cbr\u003e\n    Position: Assistant Professor\u003cbr\u003e\n    Homepage: https://vinodkkurmi.github.io/\

# %%
from google.colab import files
files.download("iiserb_graph.html")
